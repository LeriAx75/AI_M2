# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %%
url = "https://ecobici.cdmx.gob.mx/wp-content/uploads/2025/08/2025-07.csv"
csv_file_name = "data.csv"

try:
    response = requests.get(url, timeout=1200)
    response.raise_for_status()
    print("Descarga completada con éxito")
except requests.exceptions.Timeout as e:
    print(f"Error de timeout durante la descarga: {e}")
    df_raw = pd.DataFrame
except requests.exceptions.RequestException as e:
    print(f"Error durante la descarga: {e}")
    df_raw = pd.DataFrame()
# Out:
# Descarga completada con éxito

# %%
with open(csv_file_name, 'wb') as f:
    f.write(response.content)
print(f"Archivo  guardado como {csv_file_name}")

print(f"Leyendo datos desde: {csv_file_name}")
df_ecobici = pd.read_csv(csv_file_name)
df_airbnb = pd.read_csv('listings.csv')
print("Extracción completada con éxito")
# Out:
# Archivo  guardado como data.csv
# Leyendo datos desde: data.csv
# Extracción completada con éxito

# %% [markdown]
# # Media

# %%
media_ecobici = df_ecobici.select_dtypes(include=[np.number]).mean()
media_airbnb = df_airbnb.select_dtypes(include=[np.number]).mean()

# %%
plt.figure(figsize=(8,4))
media_ecobici.plot(kind='bar', color='skyblue')
plt.title('Medias de ecobici')
plt.ylabel('Medias')
plt.xlabel('Características')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))
media_airbnb.plot(kind='bar', color='skyblue')
plt.title('Medias de airbnb')
plt.ylabel('Medias')
plt.xlabel('Características')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Moda

# %%
moda_ecobici = df_ecobici.mode()
moda_airbnb = df_airbnb.mode()

# %%
plt.figure(figsize=(8,4))
moda_ecobici.plot(kind='bar', color='skyblue')
plt.title('Modas de ecobici')
plt.ylabel('Modas')
plt.xlabel('Características')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))
moda_airbnb.plot(kind='bar', color='skyblue')
plt.title('Modas de airbnb')
plt.ylabel('Modas')
plt.xlabel('Características')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\arely\AppData\Local\Temp\ipykernel_40500\1956349094.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # Mediana

# %%
mediana_ecobici = df_ecobici.select_dtypes(include=[np.number]).median()
mediana_airbnb = df_airbnb.select_dtypes(include=[np.number]).median()

# %%
plt.figure(figsize=(8,4))
mediana_ecobici.plot(kind='bar', color='skyblue')
plt.title('Mediana de ecobici')
plt.ylabel('Mediana')
plt.xlabel('Características')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))
mediana_airbnb.plot(kind='bar', color='skyblue')
plt.title('Mediana de airbnb')
plt.ylabel('Mediana')
plt.xlabel('Características')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
